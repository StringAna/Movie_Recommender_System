# %%
import pandas as pd
import os

# Set the data directory path
data_dir = 'data'

# Dictionary to store dataframes
dfs = {}

# List of CSV files to load
csv_files = ['genome-scores.csv', 'genome-tags.csv', 'links.csv', 
             'movies.csv', 'ratings.csv', 'tags.csv']

# Load each CSV file and display first 3 rows
for file in csv_files:
    file_path = os.path.join(data_dir, file)
    df = pd.read_csv(file_path)
    dfs[file] = df
    print(f"\n=== First 3 rows of {file} ===")
    print(df.head(3))
    print("\nShape:", df.shape)
    print("Columns:", df.columns.tolist())
    print("-" * 80)
# Out:
# === First 3 rows of genome-scores.csv ===
#    movieId  tagId  relevance
# 0        1      1    0.02875
# 1        1      2    0.02375
# 2        1      3    0.06250
#
# Shape: (15584448, 3)
# Columns: ['movieId', 'tagId', 'relevance']
# --------------------------------------------------------------------------------
#
# === First 3 rows of genome-tags.csv ===
#    tagId           tag
# 0      1           007
# 1      2  007 (series)
# 2      3  18th century
#
# Shape: (1128, 2)
# Columns: ['tagId', 'tag']
# --------------------------------------------------------------------------------
#
# === First 3 rows of links.csv ===
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
#
# Shape: (62423, 3)
# Columns: ['movieId', 'imdbId', 'tmdbId']
# --------------------------------------------------------------------------------
#
# === First 3 rows of movies.csv ===
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
#
# Shape: (62423, 3)
# Columns: ['movieId', 'title', 'genres']
# --------------------------------------------------------------------------------
#
# === First 3 rows of ratings.csv ===
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
#
# Shape: (25000095, 4)
# Columns: ['userId', 'movieId', 'rating', 'timestamp']
# --------------------------------------------------------------------------------
#
# === First 3 rows of tags.csv ===
#    userId  movieId          tag   timestamp
# 0       3      260      classic  1439472355
# 1       3      260       sci-fi  1439472256
# 2       4     1732  dark comedy  1573943598
#
# Shape: (1093360, 4)
# Columns: ['userId', 'movieId', 'tag', 'timestamp']
# --------------------------------------------------------------------------------
